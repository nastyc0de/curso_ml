# %% [markdown]
# ## Funciones de distribucion de probabilidades
# ### Distribucion Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.random.uniform(1, 100, 200)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([18., 17., 24., 20., 24., 19., 19., 14., 19., 26.]),
#  array([ 1.25134816, 11.11260959, 20.97387102, 30.83513245, 40.69639388,
#         50.55765532, 60.41891675, 70.28017818, 80.14143961, 90.00270104,
#         99.86396247]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Distribucion Normal

# %%
data = np.random.randn(100000)
data
# Out:
# array([-0.00648586, -0.91359536,  1.31950298, ..., -1.08320771,
#         0.96945258, -1.21066189])

# %%
x = range(1, 100001)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([5.0000e+00, 1.1400e+02, 1.5490e+03, 9.1210e+03, 2.6106e+04,
#         3.4415e+04, 2.1529e+04, 6.2520e+03, 8.6100e+02, 4.8000e+01]),
#  array([-4.8200651 , -3.92353606, -3.02700701, -2.13047797, -1.23394892,
#         -0.33741987,  0.55910917,  1.45563822,  2.35216727,  3.24869631,
#          4.14522536]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x, sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([  21.,  135.,  728., 1967., 3079., 2506., 1187.,  323.,   46.,
#            8.]),
#  array([-3.72610555, -1.77150576,  0.18309403,  2.13769381,  4.0922936 ,
#          6.04689339,  8.00149318,  9.95609297, 11.91069275, 13.86529254,
#         15.81989233]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Simulacion de Monte Carlo

# %% [markdown]
# * Generamos dos numeros aleatorios `x` e `y` entre 0 y 1.
# * Calculamos xx + yy:
#     * Se el valor es inferior a 1 -> estamos dentro del circulo.
#     * Se el valor es superior a 1 -> estamos fuera del circulo.
# * Calculamos el numero total de veces que estan dentro del circulo y lo dividimos entre el numero total de intentos para obtener una aproximacion de la probabilidad de caer dentro del circulo.
# * Usamos dicha probabiliada para aproximar el valor de `pi`.
# * Repetimos el experimento un numero de veces (n) para obtener (n) diferentes aproximaciones de `pi`.
# * Calculamos el promedio de los (n) experimentos anteriores para dar un valor final de `pi`.

# %%
pi_avg = 0
n = 1000
pi_list = []
for _ in range(100):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for i in range(n):
        z = np.sqrt(x[i]*x[i] + y[i]*y[i])
        if z <= 1:
            value +=1
    float_value = float(value)
    pi_value = float_value*4 /n
    pi_list.append(pi_value)
    pi_avg += pi_value

pi = pi_avg/100
print(pi)
plt.plot(pi_list)
# Out:
# 3.1396400000000013

# %% [markdown]
# ### Dummy Data Sets

# %%
data = pd.DataFrame(
    {
        'A': np.random.randn(10),
        'B': 1.5 + 2.5*np.random.randn(10),
        'C': np.random.uniform(5, 32, 10)
    }
)

# %%
data
# Out:
#           A         B          C
# 0 -0.382407  0.503634  22.785228
# 1 -1.174268  1.505246   5.615543
# 2  0.195074  0.793224  16.063574
# 3  0.959519  0.355752  11.383306
# 4  0.903452  2.056831  27.204651
# 5  2.119492  1.616209  27.144818
# 6  1.460444  0.472576  16.453690
# 7 -0.565555  4.356932   6.718282
# 8 -0.926228  4.307224  19.705477
# 9 -1.704648  1.468271  17.750395

# %%
data = pd.read_csv('./datasets/customer-churn-model/Customer Churn Model.txt')

# %%
col_names = data.columns.values.tolist()

# %%
a = len(col_names)

# %%
new_data = pd.DataFrame(
    {
        'Column Name': col_names,
        'A': np.random.randn(a),
        'B': np.random.uniform(0, 1, a)
    }
)
