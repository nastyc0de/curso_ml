# %% [markdown]
# ## Funciones de distribucion de probabilidades
# ### Distribucion Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.random.uniform(1, 100, 200)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([16., 25., 18., 25., 17., 22., 15., 18., 21., 23.]),
#  array([ 1.19707671, 10.97443597, 20.75179522, 30.52915448, 40.30651374,
#         50.08387299, 59.86123225, 69.6385915 , 79.41595076, 89.19331002,
#         98.97066927]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Distribucion Normal

# %%
data = np.random.randn(100000)
data
# Out:
# array([ 0.52865535, -0.79649384, -0.51758113, ...,  2.29889917,
#         2.25122441, -0.31806634])

# %%
x = range(1, 100001)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([2.0000e+01, 2.7700e+02, 3.0580e+03, 1.4667e+04, 3.2074e+04,
#         3.2035e+04, 1.4526e+04, 3.0480e+03, 2.8600e+02, 9.0000e+00]),
#  array([-4.58842244e+00, -3.67006185e+00, -2.75170127e+00, -1.83334068e+00,
#         -9.14980087e-01,  3.38050173e-03,  9.21741091e-01,  1.84010168e+00,
#          2.75846227e+00,  3.67682286e+00,  4.59518345e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x, sorted(data))

# %%
mu = 5.5
sd = 2.5
data = mu + sd*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([  19.,  184.,  793., 1882., 2832., 2429., 1310.,  448.,   91.,
#           12.]),
#  array([-3.20899282, -1.3871744 ,  0.43464402,  2.25646244,  4.07828086,
#          5.90009928,  7.7219177 ,  9.54373612, 11.36555454, 13.18737296,
#         15.00919138]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Simulacion de Monte Carlo

# %% [markdown]
# * Generamos dos numeros aleatorios `x` e `y` entre 0 y 1.
# * Calculamos xx + yy:
#     * Se el valor es inferior a 1 -> estamos dentro del circulo.
#     * Se el valor es superior a 1 -> estamos fuera del circulo.
# * Calculamos el numero total de veces que estan dentro del circulo y lo dividimos entre el numero total de intentos para obtener una aproximacion de la probabilidad de caer dentro del circulo.
# * Usamos dicha probabiliada para aproximar el valor de `pi`.
# * Repetimos el experimento un numero de veces (n) para obtener (n) diferentes aproximaciones de `pi`.
# * Calculamos el promedio de los (n) experimentos anteriores para dar un valor final de `pi`.

# %%
pi_avg = 0
n = 1000
pi_list = []
for _ in range(100):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for i in range(n):
        z = np.sqrt(x[i]*x[i] + y[i]*y[i])
        if z <= 1:
            value +=1
    float_value = float(value)
    pi_value = float_value*4 /n
    pi_list.append(pi_value)
    pi_avg += pi_value

pi = pi_avg/100
print(pi)
plt.plot(pi_list)
# Out:
# 3.1430800000000017

# %% [markdown]
# ### Dummy Data Sets

# %%
data = pd.DataFrame(
    {
        'A': np.random.randn(10),
        'B': 1.5 + 2.5*np.random.randn(10),
        'C': np.random.uniform(5, 32, 10)
    }
)

# %%
data
# Out:
#           A         B          C
# 0 -0.010597  3.770664  12.430991
# 1 -1.100768  0.905519   5.364312
# 2 -0.300584  3.990380  30.948719
# 3 -0.006875  0.285305  11.604098
# 4  0.730159 -0.265884   6.055150
# 5 -1.964859  1.675245  10.469187
# 6  1.154063 -0.117480  13.268040
# 7 -0.220254 -1.726753   8.636919
# 8 -1.636469  2.886304  24.784235
# 9  0.826437 -1.585354  14.977670

# %%
data = pd.read_csv('./datasets/customer-churn-model/Customer Churn Model.txt')

# %%
col_names = data.columns.values.tolist()

# %%
a = len(col_names)

# %%
new_data = pd.DataFrame(
    {
        'Column Name': col_names,
        'A': np.random.randn(a),
        'B': np.random.uniform(0, 1, a)
    }
)
